# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Ecommerce_Consumer_Behavior_Analysis_Data.csv")
df.head(100)
# Out:
#     Customer_ID  Age      Gender Income_Level Marital_Status Education_Level  \
# 0   37-611-6911   22      Female       Middle        Married      Bachelor's
# 1   29-392-9296   49        Male         High        Married     High School
# 2   84-649-5117   24      Female       Middle         Single        Master's
# 3   48-980-6078   29      Female       Middle         Single        Master's
# 4   91-170-9072   33      Female       Middle        Widowed     High School
# ..          ...  ...         ...          ...            ...             ...
# 95  74-509-4985   19      Female         High         Single     High School
# 96  05-857-1572   23      Female       Middle        Widowed      Bachelor's
# 97  26-521-8328   49      Female       Middle       Divorced      Bachelor's
# 98  31-147-6197   23  Non-binary         High       Divorced     High School
# 99  90-093-0469   42        Male       Middle       Divorced      Bachelor's
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Customer_ID                            1000 non-null   object
#  1   Age                                    1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Income_Level                           1000 non-null   object
#  4   Marital_Status                         1000 non-null   object
#  5   Education_Level                        1000 non-null   object
#  6   Occupation                             1000 non-null   object
#  7   Location                               1000 non-null   object
#  8   Purchase_Category                      1000 non-null   object
#  9   Purchase_Amount                        1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID                                0
# Age                                        0
# Gender                                     0
# Income_Level                               0
# Marital_Status                             0
# Education_Level                            0
# Occupation                                 0
# Location                                   0
# Purchase_Category                          0
# Purchase_Amount                            0
# Frequency_of_Purchase                      0
# Purchase_Channel                           0
# Brand_Loyalty                              0
# Product_Rating                             0
# Time_Spent_on_Product_Research(hours)      0
# Social_Media_Influence                   247
# Discount_Sensitivity                       0
# Return_Rate                                0
# Customer_Satisfaction                      0
# Engagement_with_Ads                      256
# Device_Used_for_Shopping                   0
# ...

# %%
df["Social_Media_Influence"].head()
# Out:
# 0       NaN
# 1    Medium
# 2       Low
# 3      High
# 4    Medium
# Name: Social_Media_Influence, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Customer_ID                            1000 non-null   object
#  1   Age                                    1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Income_Level                           1000 non-null   object
#  4   Marital_Status                         1000 non-null   object
#  5   Education_Level                        1000 non-null   object
#  6   Occupation                             1000 non-null   object
#  7   Location                               1000 non-null   object
#  8   Purchase_Category                      1000 non-null   object
#  9   Purchase_Amount                        1000 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Frequency_of_Purchase  Brand_Loyalty  Product_Rating  \
# count  1000.000000            1000.000000    1000.000000     1000.000000
# mean     34.304000               6.945000       3.026000        3.033000
# std       9.353238               3.147361       1.416803        1.436654
# min      18.000000               2.000000       1.000000        1.000000
# 25%      26.000000               4.000000       2.000000        2.000000
# 50%      34.500000               7.000000       3.000000        3.000000
# 75%      42.000000              10.000000       4.000000        4.000000
# max      50.000000              12.000000       5.000000        5.000000
#
#        Time_Spent_on_Product_Research(hours)  Return_Rate  \
# count                            1000.000000  1000.000000
# mean                                1.013030     0.954000
# std                                 0.791802     0.810272
# min                                 0.000000     0.000000
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Age",hue="Return_Rate",data=df)
plt.show()

# %%
print(df['Gender'].value_counts())
# Out:
# Gender
# Female         452
# Male           449
# Bigender        20
# Agender         19
# Genderfluid     17
# Non-binary      16
# Polygender      15
# Genderqueer     12
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Gender",data=df)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x="Income_Level",hue="Gender",data=df)
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.countplot(hue="Gender",x="Frequency_of_Purchase",data=df)
plt.show()

# %%
df["Purchase_Amount"].head()
df["Purchase_Amount"].dtype
df["Purchase_Amount"].unique()
# Out:
# array(['$333.80 ', '$222.22 ', '$426.22 ', '$101.31 ', '$211.70 ',
#        '$487.95 ', '$486.40 ', '$218.06 ', '$201.96 ', '$418.83 ',
#        '$389.70 ', '$238.93 ', '$61.22 ', '$79.81 ', '$58.51 ',
#        '$109.29 ', '$356.45 ', '$236.99 ', '$454.39 ', '$490.75 ',
#        '$463.07 ', '$56.74 ', '$371.32 ', '$461.00 ', '$253.37 ',
#        '$136.53 ', '$489.05 ', '$81.91 ', '$135.80 ', '$382.24 ',
#        '$354.70 ', '$433.82 ', '$282.13 ', '$454.38 ', '$138.88 ',
#        '$52.34 ', '$338.20 ', '$263.15 ', '$371.58 ', '$353.40 ',
#        '$329.41 ', '$54.46 ', '$257.12 ', '$293.04 ', '$110.40 ',
#        '$76.27 ', '$392.08 ', '$51.22 ', '$227.57 ', '$378.87 ',
#        '$423.92 ', '$111.24 ', '$299.31 ', '$169.28 ', '$449.13 ',
#        '$427.48 ', '$171.61 ', '$240.28 ', '$310.17 ', '$166.00 ',
#        '$362.01 ', '$348.50 ', '$395.97 ', '$474.99 ', '$286.43 ',
#        '$333.32 ', '$223.47 ', '$414.83 ', '$391.38 ', '$368.40 ',
# ...

# %%
df["Purchase_Amount"] = df['Purchase_Amount'].astype(str).str.replace('$',"",regex=False).str.strip().astype(float)
print(df["Purchase_Amount"].head())
df["Purchase_Amount"].dtype
# Out:
# 0    333.80
# 1    222.22
# 2    426.22
# 3    101.31
# 4    211.70
# Name: Purchase_Amount, dtype: float64
# dtype('float64')

# %%
print(df['Social_Media_Influence'].isnull().sum())
print(df['Social_Media_Influence'].unique())
# Out:
# 247
# [nan 'Medium' 'Low' 'High']

# %%
mode_social_media_influence = df['Social_Media_Influence'].mode()[0]
df['Social_Media_Influence'].fillna(mode_social_media_influence, inplace=True)
print(df['Social_Media_Influence'].isnull().sum())
print(df['Social_Media_Influence'].unique())
# Out:
# 0
# ['High' 'Medium' 'Low']

# %%
print(df['Engagement_with_Ads'].isnull().sum())
print(df['Engagement_with_Ads'].unique())
# Out:
# 256
# [nan 'High' 'Low' 'Medium']

# %%
mode_engagement_with_ads = df['Engagement_with_Ads'].mode()[0]
df['Engagement_with_Ads'].fillna(mode_engagement_with_ads, inplace=True)
print(df['Engagement_with_Ads'].isnull().sum())
print(df['Engagement_with_Ads'].unique())
# Out:
# 0
# ['High' 'Low' 'Medium']

# %%
df["Time_oof_Purchase"] = pd.to_datetime(df['Time_of_Purchase'])
print(df["Time_of_Purchase"].head())
print(df['Time_of_Purchase'].dtype)
# Out:
# 0     3/1/2024
# 1    4/16/2024
# 2    3/15/2024
# 3    10/4/2024
# 4    1/30/2024
# Name: Time_of_Purchase, dtype: object
# object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Customer_ID                            1000 non-null   object
#  1   Age                                    1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Income_Level                           1000 non-null   object
#  4   Marital_Status                         1000 non-null   object
#  5   Education_Level                        1000 non-null   object
#  6   Occupation                             1000 non-null   object
#  7   Location                               1000 non-null   object
#  8   Purchase_Category                      1000 non-null   object
#  9   Purchase_Amount                        1000 non-null   float64
# ...

# %%
Social_Media_Influence
Engagement_with_Ads

# %%
sns.boxplot(x='Frequency_of_Purchase', y='Engagement_with_Ads', data=df)
plt.title('Engagement vs Purchase Behavior')
plt.show()
